# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df = pd.read_excel("100k_filtered_raw_bug_reports.xlsx")
df.sample(5)
# Out:
#                       author         creation_time   bug_id  \
# 42970   wptsync@mozilla.bugs  2021-06-18T14:35:26Z  1717219
# 28597   wptsync@mozilla.bugs  2021-08-05T23:39:52Z  1724328
# 20044   wptsync@mozilla.bugs  2021-08-30T10:47:43Z  1728088
# 33257  bytesized@mozilla.com  2021-07-23T21:49:25Z  1722098
# 58734    lhansen@mozilla.com  2021-04-30T16:16:36Z  1708743
#
#                                                     text  Bug report  \
# 42970  sync web-platform-tests pr 29433 into mozilla-...        True
# 28597  sync web-platform-tests pr 29924 into mozilla-...        True
# 20044  sync web-platform-tests pr 30226 into mozilla-...        True
# 33257  str: 1. download the fzf binary and copy it to...        True
# 58734  we should experiment with avx2 support for sim...        True
#
#        author_id    status resolution  contains_steps_to_reproduce
# 42970   611017.0  RESOLVED      FIXED                        False
# ...

# %%
len(df['bug_id'].unique())
# Out:
# 83550

# %%
len(df)
# Out:
# 119585

# %%
len(df[df.duplicated()])
# Out:
# 36034

# %%
df[df.duplicated()]
# Out:
#                             author         creation_time   bug_id  \
# 1              itiel_yn8@walla.com  2022-11-19T21:20:37Z  1801502
# 8              egorgrits@gmail.com  2022-11-19T17:03:32Z  1801488
# 9              egorgrits@gmail.com  2022-11-19T17:03:32Z  1801488
# 10             egorgrits@gmail.com  2022-11-19T17:03:32Z  1801488
# 12               nerli@mozilla.com  2022-11-19T12:54:41Z  1801479
# ...                            ...                   ...      ...
# 71075          dave.hunt@gmail.com  2021-03-28T17:07:50Z  1701511
# 71076          dave.hunt@gmail.com  2021-03-28T17:07:50Z  1701511
# 71078  dietrich@webtransitions.org  2021-03-28T16:54:32Z  1701510
# 71079  dietrich@webtransitions.org  2021-03-28T16:54:32Z  1701510
# 71080  dietrich@webtransitions.org  2021-03-28T16:54:32Z  1701510
#
#                                                     text  Bug report  \
# 1      created attachment 9304261screenshotthis is es...        True
# ...

# %%
final_status_df = df.drop_duplicates().sort_values('creation_time').groupby('bug_id').last().reset_index()

# %%
print(final_status_df)
# Out:
#         bug_id                 author         creation_time  \
# 0      1689124   wlach@protonmail.com  2021-01-27T15:34:41Z
# 1      1689126  cpeterson@mozilla.com  2021-01-27T15:42:54Z
# 2      1689128  bobowencode@gmail.com  2021-01-27T15:51:35Z
# 3      1689131       nhnt11@gmail.com  2021-01-27T16:06:03Z
# 4      1689136  bobowencode@gmail.com  2021-01-27T16:28:26Z
# ...        ...                    ...                   ...
# 83545  1931479     update-bot@bmo.tld  2024-11-15T06:31:58Z
# 83546  1931480    ajoltan@mozilla.com  2024-11-15T07:02:04Z
# 83547  1931481    ajoltan@mozilla.com  2024-11-15T07:12:31Z
# 83548  1931493      chenx97@gmail.com  2024-11-15T09:10:14Z
# 83549  1931496        jwatt@jwatt.org  2024-11-15T09:20:03Z
#
#                                                     text  Bug report  \
# 0      there are multiple options for scheduling quer...        True
# 1      a crash event can have no report payload if th...        True
# ...

# %%
df['resolution'].value_counts()
# Out:
# resolution
# FIXED    119585
# Name: count, dtype: int64

# %%
df['status'].value_counts()
# Out:
# status
# RESOLVED    106885
# VERIFIED     12700
# Name: count, dtype: int64

# %%
df['status'].unique()
# Out:
# <StringArray>
# ['VERIFIED', 'RESOLVED']
# Length: 2, dtype: str

# %%
df[df.duplicated() == False]
# Out:
#                       author         creation_time   bug_id  \
# 0        itiel_yn8@walla.com  2022-11-19T21:20:37Z  1801502
# 2         0xgodson@gmail.com  2022-11-19T21:02:27Z  1801501
# 3           emilio@crisal.io  2022-11-19T20:58:00Z  1801500
# 4       wptsync@mozilla.bugs  2022-11-19T20:48:45Z  1801498
# 5            mak@mozilla.com  2022-11-19T19:42:23Z  1801495
# ...                      ...                   ...      ...
# 119580  redlibrepy@gmail.com  2022-11-20T00:43:27Z  1801521
# 119581      emilio@crisal.io  2022-11-20T00:09:18Z  1801517
# 119582   itiel_yn8@walla.com  2022-11-19T23:15:52Z  1801515
# 119583   itiel_yn8@walla.com  2022-11-19T23:08:00Z  1801514
# 119584      ch4sys@gmail.com  2022-11-19T22:56:47Z  1801512
#
#                                                      text  Bug report  \
# 0       created attachment 9304261screenshotthis is es...        True
# 2       created attachment 9304259index.htmlbrowser us...        True
# ...

# %%
len(df[df.duplicated() == False])
# Out:
# 83551

# %%
len(df[df.duplicated() == False]['bug_id'].unique())
# Out:
# 83550
